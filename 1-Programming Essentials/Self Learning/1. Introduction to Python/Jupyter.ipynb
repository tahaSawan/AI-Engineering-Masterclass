# %% [markdown]
# # Hello Just testing things out

# %%
print("Tabodiii")
# Out:
# Tabodiii

# %% [markdown]
# ## Lets do Addition

# %%
5+3
# Out:
# 8

# %% [markdown]
# ## Comditional Statements

# %%
if 5 > 3:
    print("5 is greater than 3")
else:
    print("Tabodi")
# Out:
# 5 is greater than 3
