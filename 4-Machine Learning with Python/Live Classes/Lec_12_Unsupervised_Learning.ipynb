# %% [markdown]
# ## Unsupervised Learning

# %% [markdown]
# #### Hierarchichal Learning

# %%
import scipy.cluster.hierarchy as shc
import pandas as pd

# %%
df1=pd.read_csv('Mall_customers.csv')

# %%
df1=iloc[]
